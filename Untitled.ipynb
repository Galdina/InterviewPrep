# %%
#import libraries 
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as scs

# %%
#check bernoulli distribution
bernoulli_d = scs.bernoulli(p=0.5)

# %%
bernoulli_d_sample = scs.bernoulli.rvs(p=0.5, loc=0, size=10)
bernoulli_d_sample
# Out:
# array([1, 1, 0, 0, 1, 0, 1, 1, 1, 0])

# %%
n = 1
x_points = np.linspace(0,n,2)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PMF")
ax2.set_title("CDF")

ax1.plot(x_points, bernoulli_d.pmf(x_points))
plt.grid(True, color = "grey", linewidth = "1.4", linestyle = "-.") 
  
ax2.plot(x_points, bernoulli_d.cdf(x_points))
plt.grid(True, color = "grey", linewidth = "1.4", linestyle = "-.")

# %%
bernoulli_d.cdf(x=0.75)
# Out:
# 0.5

# %%
#Binomial
binomial_d = scs.binom(n=50, p=0.5)

# %%
binomial_d.mean(), binomial_d.var()
# Out:
# (25.0, 12.5)

# %%
binomial_d.pmf(k=20), binomial_d.pmf(k=25)
# Out:
# (0.04185914925255192, 0.11227517265921609)

# %%
binomial_d_sample = scs.binom.rvs(n=50, p=0.5, loc=0, size=20)
binomial_d_sample
# Out:
# array([17, 34, 26, 26, 28, 30, 22, 24, 22, 27, 22, 24, 20, 25, 26, 27, 22,
#        27, 22, 24])

# %%
binomial_d.rvs(size=30)
# Out:
# array([29, 35, 21, 26, 32, 25, 23, 25, 29, 24, 22, 27, 26, 25, 25, 21, 20,
#        26, 24, 27, 24, 23, 21, 31, 25, 19, 19, 27, 21, 26])

# %%
x_points = np.linspace(0,n,n+1)
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title("PMF")
ax2.set_title("CDF")

ax1.plot(x_points, binomial_d.pmf(x_points))
ax2.plot(x_points, binomial_d.cdf(x_points))
